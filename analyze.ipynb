# %%
import pandas as pd
import numpy as np
import time
from stable_baselines.common.vec_env import DummyVecEnv

# preprocessor
from preprocessing.preprocessors import *
# config
from config.config import *
# model
from model.models import *
import os
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
data = pd.read_csv("done_data.csv",index_col=0)

# %%
data.shape
# Out:
# (87780, 12)

# %%
data.columns
# Out:
# Index(['datadate', 'tic', 'adjcp', 'open', 'high', 'low', 'volume', 'macd',
#        'rsi', 'cci', 'adx', 'turbulence'],
#       dtype='object')

# %%
data.head()
# Out:
#    datadate   tic      adjcp       open       high        low      volume  \
# 0  20090102  AAPL  12.964286  12.268571  13.005714  12.165714  26641980.0
# 1  20090102   AXP  19.330000  18.570000  19.520000  18.400000  10955620.0
# 2  20090102    BA  45.250000  42.800000  45.560000  42.780000   7010171.0
# 3  20090102   CAT  46.910000  44.910000  46.980000  44.710000   7116726.0
# 4  20090102  CSCO  16.960000  16.410000  17.000000  16.250000  40977480.0
#
#    macd    rsi        cci    adx  turbulence
# 0   0.0  100.0  66.666667  100.0         0.0
# 1   0.0  100.0  66.666667  100.0         0.0
# 2   0.0  100.0  66.666667  100.0         0.0
# 3   0.0    0.0  66.666667  100.0         0.0
# 4   0.0  100.0  66.666667  100.0         0.0

# %%
data = preprocess_data()

# %%
data.head()
# Out:
#    datadate   tic      adjcp       open       high        low      volume  \
# 0  20090102  AAPL  12.964286  12.268571  13.005714  12.165714  26641980.0
# 1  20090102   AXP  19.330000  18.570000  19.520000  18.400000  10955620.0
# 2  20090102    BA  45.250000  42.800000  45.560000  42.780000   7010171.0
# 3  20090102   CAT  46.910000  44.910000  46.980000  44.710000   7116726.0
# 4  20090102  CSCO  16.960000  16.410000  17.000000  16.250000  40977480.0
#
#    macd    rsi        cci    adx  turbulence
# 0   0.0  100.0  66.666667  100.0         0.0
# 1   0.0  100.0  66.666667  100.0         0.0
# 2   0.0  100.0  66.666667  100.0         0.0
# 3   0.0    0.0  66.666667  100.0         0.0
# 4   0.0  100.0  66.666667  100.0         0.0

# %%
data = add_turbulence(data)

# %%
print(data.head())
print(data.size)
# Out:
#    datadate   tic      adjcp       open       high        low      volume  \
# 0  20090102  AAPL  12.964286  12.268571  13.005714  12.165714  26641980.0
# 1  20090102   AXP  19.330000  18.570000  19.520000  18.400000  10955620.0
# 2  20090102    BA  45.250000  42.800000  45.560000  42.780000   7010171.0
# 3  20090102   CAT  46.910000  44.910000  46.980000  44.710000   7116726.0
# 4  20090102  CSCO  16.960000  16.410000  17.000000  16.250000  40977480.0
#
#    macd    rsi        cci    adx  turbulence
# 0   0.0  100.0  66.666667  100.0         0.0
# 1   0.0  100.0  66.666667  100.0         0.0
# 2   0.0  100.0  66.666667  100.0         0.0
# 3   0.0    0.0  66.666667  100.0         0.0
# 4   0.0  100.0  66.666667  100.0         0.0
# 1053360

# %%
unique_trade_date = data[(data.datadate > 20151001)&(data.datadate <= 20200707)].datadate.unique()

# %%
rebalance_window = 63
validation_window = 63

# %%
run_ensemble_strategy(
    df=data,
    unique_trade_date= unique_trade_date,
    rebalance_window = rebalance_window,
    validation_window=validation_window
)
# Out:
# is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/distributions.py:418: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/a2c/a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/tensorflow_core/python/ops/clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/a2c/a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/a2c/a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/a2c/a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Training time (A2C):  3.6941731254259746  minutes
# ======A2C Validation from:  20151002 to  20160104
# A2C Sharpe Ratio:  -0.06364843140399971
# ======PPO Training========
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# Training time (PPO):  13.33636402686437  minutes
# ======PPO Validation from:  20151002 to  20160104
# PPO Sharpe Ratio:  0.06356693646377345
# ======DDPG Training========
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/ddpg/policies.py:136: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py:94: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py:444: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sasidhar/miniconda3/envs/drlproject/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:432: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# Training time (DDPG):  2.3284684975941974  minutes
# ======DDPG Validation from:  20151002 to  20160104
# ======Trading from:  20160104 to  20160405
# previous_total_asset:1000000
# end_total_asset:1074176.8752992693
# total_reward:74176.87529926933
# total_cost:  5066.93442052057
# total trades:  1506
# Sharpe:  0.25250990105386467
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20160104
# ======A2C Training========
# Training time (A2C):  3.535610055923462  minutes
# ======A2C Validation from:  20160104 to  20160405
# A2C Sharpe Ratio:  0.11528151015736354
# ======PPO Training========
# Training time (PPO):  12.095626223087312  minutes
# ======PPO Validation from:  20160104 to  20160405
# PPO Sharpe Ratio:  0.01858802241105262
# ======DDPG Training========
# Training time (DDPG):  2.278325168291728  minutes
# ======DDPG Validation from:  20160104 to  20160405
# ======Trading from:  20160405 to  20160705
# previous_total_asset:1074176.8752992693
# end_total_asset:1077884.0674819127
# total_reward:3707.192182643339
# total_cost:  4384.199535278563
# total trades:  1440
# Sharpe:  0.02141185311922076
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20160405
# ======A2C Training========
# Training time (A2C):  3.91865553855896  minutes
# ======A2C Validation from:  20160405 to  20160705
# A2C Sharpe Ratio:  -0.0018242077958993115
# ======PPO Training========
# Training time (PPO):  12.476735945542654  minutes
# ======PPO Validation from:  20160405 to  20160705
# PPO Sharpe Ratio:  0.09598556747945411
# ======DDPG Training========
# Training time (DDPG):  2.259896449247996  minutes
# ======DDPG Validation from:  20160405 to  20160705
# ======Trading from:  20160705 to  20161003
# previous_total_asset:1077884.0674819127
# end_total_asset:1109885.8379543005
# total_reward:32001.770472387783
# total_cost:  4141.811699551811
# total trades:  1456
# Sharpe:  0.14682186855982904
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20160705
# ======A2C Training========
# Training time (A2C):  3.676989750067393  minutes
# ======A2C Validation from:  20160705 to  20161003
# A2C Sharpe Ratio:  -0.022622198653644485
# ======PPO Training========
# Training time (PPO):  13.66495353380839  minutes
# ======PPO Validation from:  20160705 to  20161003
# PPO Sharpe Ratio:  0.013340014768175257
# ======DDPG Training========
# Training time (DDPG):  2.560238699118296  minutes
# ======DDPG Validation from:  20160705 to  20161003
# ======Trading from:  20161003 to  20170103
# previous_total_asset:1109885.8379543005
# end_total_asset:1200378.175188952
# total_reward:90492.33723465144
# total_cost:  5592.676519190692
# total trades:  1471
# Sharpe:  0.4132604513616078
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20161003
# ======A2C Training========
# Training time (A2C):  4.838169264793396  minutes
# ======A2C Validation from:  20161003 to  20170103
# A2C Sharpe Ratio:  0.5935070249684095
# ======PPO Training========
# Training time (PPO):  14.949565267562866  minutes
# ======PPO Validation from:  20161003 to  20170103
# PPO Sharpe Ratio:  0.6115476675736433
# ======DDPG Training========
# Training time (DDPG):  2.5830433487892153  minutes
# ======DDPG Validation from:  20161003 to  20170103
# ======Trading from:  20170103 to  20170404
# previous_total_asset:1200378.175188952
# end_total_asset:1278489.6720677605
# total_reward:78111.4968788086
# total_cost:  5658.112160879532
# total trades:  1490
# Sharpe:  0.368803277578154
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20170103
# ======A2C Training========
# Training time (A2C):  4.435703198115031  minutes
# ======A2C Validation from:  20170103 to  20170404
# A2C Sharpe Ratio:  0.10010451777651272
# ======PPO Training========
# Training time (PPO):  14.889675438404083  minutes
# ======PPO Validation from:  20170103 to  20170404
# PPO Sharpe Ratio:  0.07630761691048565
# ======DDPG Training========
# Training time (DDPG):  2.560271739959717  minutes
# ======DDPG Validation from:  20170103 to  20170404
# ======Trading from:  20170404 to  20170705
# previous_total_asset:1278489.6720677605
# end_total_asset:1330300.0522161291
# total_reward:51810.380148368655
# total_cost:  4170.300939289695
# total trades:  955
# Sharpe:  0.31387792516636903
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20170404
# ======A2C Training========
# Training time (A2C):  3.614980411529541  minutes
# ======A2C Validation from:  20170404 to  20170705
# A2C Sharpe Ratio:  0.3059069089719963
# ======PPO Training========
# Training time (PPO):  13.716711568832398  minutes
# ======PPO Validation from:  20170404 to  20170705
# PPO Sharpe Ratio:  0.09937630312975232
# ======DDPG Training========
# Training time (DDPG):  2.393038042386373  minutes
# ======DDPG Validation from:  20170404 to  20170705
# ======Trading from:  20170705 to  20171003
# previous_total_asset:1330300.0522161291
# end_total_asset:1431061.2704415892
# total_reward:100761.21822546003
# total_cost:  7347.98280892533
# total trades:  1486
# Sharpe:  0.5179714868983699
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20170705
# ======A2C Training========
# Training time (A2C):  4.412484486897786  minutes
# ======A2C Validation from:  20170705 to  20171003
# A2C Sharpe Ratio:  -0.04835465608599828
# ======PPO Training========
# Training time (PPO):  14.518714455763499  minutes
# ======PPO Validation from:  20170705 to  20171003
# PPO Sharpe Ratio:  0.14061022643419277
# ======DDPG Training========
# Training time (DDPG):  2.368678339322408  minutes
# ======DDPG Validation from:  20170705 to  20171003
# ======Trading from:  20171003 to  20180103
# previous_total_asset:1431061.2704415892
# end_total_asset:1602291.623405124
# total_reward:171230.35296353488
# total_cost:  455.8762076787184
# total trades:  1087
# Sharpe:  0.6240544307531203
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20171003
# ======A2C Training========
# Training time (A2C):  4.005811921755472  minutes
# ======A2C Validation from:  20171003 to  20180103
# A2C Sharpe Ratio:  0.41845361783696816
# ======PPO Training========
# Training time (PPO):  13.99302879969279  minutes
# ======PPO Validation from:  20171003 to  20180103
# PPO Sharpe Ratio:  0.38948492357473236
# ======DDPG Training========
# Training time (DDPG):  2.4348088979721068  minutes
# ======DDPG Validation from:  20171003 to  20180103
# ======Trading from:  20180103 to  20180405
# previous_total_asset:1602291.623405124
# end_total_asset:1627041.3627311732
# total_reward:24749.739326049108
# total_cost:  2101.294467588567
# total trades:  229
# Sharpe:  0.11019886542817713
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20180103
# ======A2C Training========
# Training time (A2C):  4.085921887556712  minutes
# ======A2C Validation from:  20180103 to  20180405
# A2C Sharpe Ratio:  0.04496834970354177
# ======PPO Training========
# Training time (PPO):  14.070531066258749  minutes
# ======PPO Validation from:  20180103 to  20180405
# PPO Sharpe Ratio:  -0.009722046752090971
# ======DDPG Training========
# Training time (DDPG):  2.4570161143938702  minutes
# ======DDPG Validation from:  20180103 to  20180405
# ======Trading from:  20180405 to  20180705
# previous_total_asset:1627041.3627311732
# end_total_asset:1632493.0920330663
# total_reward:5451.729301893152
# total_cost:  6143.095283590463
# total trades:  1017
# Sharpe:  0.02582764017378281
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20180405
# ======A2C Training========
# Training time (A2C):  4.033321034908295  minutes
# ======A2C Validation from:  20180405 to  20180705
# A2C Sharpe Ratio:  0.011043194238340524
# ======PPO Training========
# Training time (PPO):  13.34759670495987  minutes
# ======PPO Validation from:  20180405 to  20180705
# PPO Sharpe Ratio:  -0.2232332082217482
# ======DDPG Training========
# Training time (DDPG):  1.2771505475044251  minutes
# ======DDPG Validation from:  20180405 to  20180705
# ======Trading from:  20180705 to  20181003
# previous_total_asset:1632493.0920330663
# end_total_asset:1656912.4617784277
# total_reward:24419.369745361386
# total_cost:  4722.168572068894
# total trades:  502
# Sharpe:  0.17926071388555564
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20180705
# ======A2C Training========
# Training time (A2C):  1.5774944464365641  minutes
# ======A2C Validation from:  20180705 to  20181003
# A2C Sharpe Ratio:  0.05583414984569451
# ======PPO Training========
# Training time (PPO):  5.1424086133639015  minutes
# ======PPO Validation from:  20180705 to  20181003
# PPO Sharpe Ratio:  0.05039699351913901
# ======DDPG Training========
# Training time (DDPG):  0.717385470867157  minutes
# ======DDPG Validation from:  20180705 to  20181003
# ======Trading from:  20181003 to  20190104
# previous_total_asset:1656912.4617784277
# end_total_asset:1671629.0920399418
# total_reward:14716.630261514103
# total_cost:  1164.814676023023
# total trades:  145
# Sharpe:  0.25652570622704646
# ============================================
# turbulence_threshold:  171.0940715631027
# ======Model training from:  20090000 to  20181003
# ======A2C Training========
# Training time (A2C):  1.4524188717206319  minutes
# ======A2C Validation from:  20181003 to  20190104
# A2C Sharpe Ratio:  -0.3606252770072996
# ======PPO Training========
# Training time (PPO):  4.983459675312043  minutes
# ======PPO Validation from:  20181003 to  20190104
# PPO Sharpe Ratio:  -0.3474725825162403
# ======DDPG Training========
# Training time (DDPG):  0.7948569814364116  minutes
# ======DDPG Validation from:  20181003 to  20190104
# ======Trading from:  20190104 to  20190405
# previous_total_asset:1671629.0920399418
# end_total_asset:1749107.8284330496
# total_reward:77478.7363931078
# total_cost:  8384.053951722224
# total trades:  1438
# Sharpe:  0.17099569559264394
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20190104
# ======A2C Training========
# Training time (A2C):  1.3187071561813355  minutes
# ======A2C Validation from:  20190104 to  20190405
# A2C Sharpe Ratio:  -0.055525769359228705
# ======PPO Training========
# Training time (PPO):  4.768048584461212  minutes
# ======PPO Validation from:  20190104 to  20190405
# PPO Sharpe Ratio:  -0.0039076413878623515
# ======DDPG Training========
# Training time (DDPG):  0.7963243405024211  minutes
# ======DDPG Validation from:  20190104 to  20190405
# ======Trading from:  20190405 to  20190708
# previous_total_asset:1749107.8284330496
# end_total_asset:1753337.3094613422
# total_reward:4229.481028292561
# total_cost:  1140.275433437231
# total trades:  145
# Sharpe:  0.2110049661587157
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20190405
# ======A2C Training========
# Training time (A2C):  1.4032692551612853  minutes
# ======A2C Validation from:  20190405 to  20190708
# A2C Sharpe Ratio:  0.2549110328347012
# ======PPO Training========
# Training time (PPO):  4.825296191374461  minutes
# ======PPO Validation from:  20190405 to  20190708
# PPO Sharpe Ratio:  0.3752033774803636
# ======DDPG Training========
# Training time (DDPG):  0.7132284482320149  minutes
# ======DDPG Validation from:  20190405 to  20190708
# ======Trading from:  20190708 to  20191004
# previous_total_asset:1753337.3094613422
# end_total_asset:1749796.2899777673
# total_reward:-3541.019483574899
# total_cost:  1943.1678193161022
# total trades:  364
# Sharpe:  -0.1138782687789429
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20190708
# ======A2C Training========
# Training time (A2C):  1.547227958838145  minutes
# ======A2C Validation from:  20190708 to  20191004
# A2C Sharpe Ratio:  -0.10426862655390011
# ======PPO Training========
# Training time (PPO):  3.922308413187663  minutes
# ======PPO Validation from:  20190708 to  20191004
# PPO Sharpe Ratio:  -0.10316759123470892
# ======DDPG Training========
# Training time (DDPG):  0.7312315225601196  minutes
# ======DDPG Validation from:  20190708 to  20191004
# ======Trading from:  20191004 to  20200106
# previous_total_asset:1749796.2899777673
# end_total_asset:1749100.6702838019
# total_reward:-695.6196939654183
# total_cost:  600.1449002951812
# total trades:  80
# Sharpe:  -0.1204996496305491
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20191004
# ======A2C Training========
# Training time (A2C):  1.5010401010513306  minutes
# ======A2C Validation from:  20191004 to  20200106
# A2C Sharpe Ratio:  -0.3159752712607159
# ======PPO Training========
# Training time (PPO):  5.17270656824112  minutes
# ======PPO Validation from:  20191004 to  20200106
# PPO Sharpe Ratio:  -0.3186895471549287
# ======DDPG Training========
# Training time (DDPG):  0.7706502040227254  minutes
# ======DDPG Validation from:  20191004 to  20200106
# ======Trading from:  20200106 to  20200406
# previous_total_asset:1749100.6702838019
# end_total_asset:1724486.517863269
# total_reward:-24614.15242053289
# total_cost:  1188.0914717571638
# total trades:  170
# Sharpe:  -0.40830620468333223
# ============================================
# turbulence_threshold:  96.08032158358284
# ======Model training from:  20090000 to  20200106
# ======A2C Training========
# Training time (A2C):  1.367228126525879  minutes
# ======A2C Validation from:  20200106 to  20200406
# A2C Sharpe Ratio:  -0.4257946152344054
# ======PPO Training========
# Training time (PPO):  4.743135209878286  minutes
# ======PPO Validation from:  20200106 to  20200406
# PPO Sharpe Ratio:  -0.4969096935696836
# ======DDPG Training========
# Training time (DDPG):  0.7995353221893311  minutes
# ======DDPG Validation from:  20200106 to  20200406
# ======Trading from:  20200406 to  20200707
# previous_total_asset:1724486.517863269
# end_total_asset:1728101.6218312897
# total_reward:3615.1039680207614
# total_cost:  641.6883013028336
# total trades:  94
# Sharpe:  0.1919568549471676
# Ensemble Strategy took:  270.5987228234609  minutes
